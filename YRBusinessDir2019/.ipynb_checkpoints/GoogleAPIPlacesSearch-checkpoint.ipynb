# %%
# This cell uses the google api and returns a json list of bubble tea places within 10km of 43.91407265468856%2C-79.44731313715351
# Ideally, this would be a flattened JSON return, but it is not

import requests

#AIzaSyBnui5g3BeTm3LcbBLBvbLrWFcwMEv6J8k
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=43.91407265468856%2C-79.44731313715351&radius=10000&keyword=bubbletea&key=AIzaSyBnui5g3BeTm3LcbBLBvbLrWFcwMEv6J8k"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "html_attributions" : [],
#    "next_page_token" : "Aap_uEDT0AvhKEvQqEF0jgZnQvA1_F5x28KLU-MaQDbHUmDh-p34TZ-Xn9gSONPYLT7LwpdS3GvI5Yx3HSqm19nTQgT3DI8fHVJNbyLitkK-drDPJzmu85tDptU6PTQvbZCIP9WiCK7Ih457oi0Lta_S6dBr7Cxi01PwR1HsdovdPb653N2XlJThl8gEQqImMRzVOq6owUs99zINWuWWG8dCHA8bkjM6bQjzo8XqV1aNjfVsrD3BgDjAd-7ClrD3Sq_lHoCZF3g76GYDgMxx2J7aUyVHyi2gXiYU7Bj2GWJxiOhMGhrhFn4J78kNH3YakqKgYGqhdFyobm_tA7gDCTPSaMoK7KpRwlDJNzWhXO7H7carDsSl_-K4yDjxloASzAhgBo0nZ6cuaBiYBsvWOu9o7RovZyDTSg9DGEUovYAORI4a8lXp_tvLd6sj9fA",
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 43.8412527,
#                "lng" : -79.3992092
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 43.84266277989273,
#                   "lng" : -79.39793562010728
#                },
#                "southwest" : {
#                   "lat" : 43.83996312010729,
# ...

# %%
# Use the FME converting to create a esri feature class, but it failed
